# %% [markdown]
# # Problemas
#
# Como vimos acima, há muitos passos na criação e definição de uma nova rede neural.
# A grande parte desses ajustes dependem diretamente do problemas.
#
# Abaixo, listamos alguns problemas. Todos os problemas e datasets usados vem do [Center for Machine Learning and Intelligent Systems](http://archive.ics.uci.edu/ml/datasets.php).
#
#
# **Seu objetivo é determinar e implementar um modelo para cada problema.**
#
# Isso inclui:
#
# 1. definir uma arquitetura.
# Por enquanto usando somente camadas [Lineares](https://pytorch.org/docs/stable/nn.html#linear), porém podemos variar as ativações, como [Sigmoid](https://pytorch.org/docs/stable/nn.html#sigmoid), [Tanh](https://pytorch.org/docs/stable/nn.html#tanh), [ReLU](https://pytorch.org/docs/stable/nn.html#relu), [LeakyReLU](https://pytorch.org/docs/stable/generated/torch.nn.LeakyReLU.html), [ELU](https://pytorch.org/docs/stable/generated/torch.nn.ELU.html), [SeLU](https://pytorch.org/docs/stable/generated/torch.nn.SELU.html), [PReLU](https://pytorch.org/docs/stable/generated/torch.nn.PReLU.html), [RReLU](https://pytorch.org/docs/stable/generated/torch.nn.RReLU.html)
# 2. definir uma função de custo. Algums opções que vimos previamente incluem[L1](https://pytorch.org/docs/stable/nn.html#l1loss), [L2/MSE](https://pytorch.org/docs/stable/nn.html#mseloss), [Huber/SmoothL1](https://pytorch.org/docs/stable/nn.html#smoothl1loss), [*Cross-Entropy*](https://pytorch.org/docs/stable/nn.html#crossentropyloss), [Hinge](https://pytorch.org/docs/stable/nn.html#hingeembeddingloss)), e
# 3. definir um algoritmo de otimização ([SGD](https://pytorch.org/docs/stable/optim.html#torch.optim.SGD), [RMSProp](https://pytorch.org/docs/stable/optim.html#torch.optim.RMSprop), [Adam](https://pytorch.org/docs/stable/optim.html#torch.optim.Adam))
#
# A leitura do dado assim como a função de treinamento já estão implementados para você.

# %% [markdown]
# # Preâmbulo

# %%
# imports basicos
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import torch
import torch.nn.functional as F
import torchvision

from torchvision import datasets, transforms
from torch import optim, nn

import os
import sys
import time
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.ion()

# %%
# Test if GPU is avaliable, if not, use cpu instead
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
n = torch.cuda.device_count()
devices_ids = list(range(n))
device
# Out:
# device(type='cpu')

# %%
# funções básicas

def load_array(features, labels, batch_size, is_train=True):
    """Construct a Torch data loader"""
    if type(features) != torch.tensor:
        features = torch.tensor(features)
    if type(labels) != torch.tensor:
        labels = torch.tensor(labels)
    dataset = torch.utils.data.TensorDataset(features, labels)
    return torch.utils.data.DataLoader(dataset, batch_size, shuffle=is_train)

def _get_batch(batch):
    """Return features and labels on ctx."""
    features, labels = batch
    if labels.type() != features.type():
        labels = labels.type(features.type())
    return (torch.nn.DataParallel(features, device_ids=devices_ids),
            torch.nn.DataParallel(labels, device_ids=devices_ids), features.shape[0])

# Função usada para calcular acurácia
def evaluate_accuracy(data_iter, net, loss):
    """Evaluate accuracy of a model on the given data set."""

    acc_sum, n, l = 0, 0, 0
    net.eval()
    with torch.no_grad():
      for X, y in data_iter:
          X, y = X.to(device), y.to(device)
          y_hat = net(X)
          l += loss(y_hat, y.long())
          acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
          n += y.size(0)

    return acc_sum / n, l.item() / len(data_iter)
  
    
# Função usada no treinamento e validação da rede
def train_validate(net, train_iter, test_iter, batch_size, trainer, loss,
                   num_epochs, type='regression'):
    print('training on', device)
    for epoch in range(num_epochs):
        net.train()
        train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()
        for X, y in train_iter:
            X, y = X.to(device), y.to(device)
            trainer.zero_grad()
            y_hat = net(X)
            if type == 'regression':
              l = loss(y_hat, y.float())
            else:
              l = loss(y_hat, y.long())
            l.backward()
            trainer.step()
            train_l_sum += l.item()
            train_acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
            n += y.size(0)
        test_acc, test_loss = evaluate_accuracy(test_iter, net, loss)
        if type == 'regression':
          print('epoch %d, train loss %.4f, test loss %.4f, time %.1f sec'
                % (epoch + 1, train_l_sum / len(train_iter), test_loss, time.time() - start))
        else:
          print('epoch %d, train loss %.4f, train acc %.3f, test loss %.4f, '
              'test acc %.3f, time %.1f sec'
              % (epoch + 1, train_l_sum / len(train_iter), train_acc_sum / n, test_loss, 
                 test_acc, time.time() - start))
          
        
# funcao usada para teste
def test(net, test_iter):
    print('testing on', device)
    net.eval()
    first = True
    for X in test_iter:
        X = X.to(device)
        y_hat = net(X)
        if first is True:
            pred_logits = y_hat
            pred_labels = y_hat.argmax(axis=1)
            first = False
        else:
            pred_logits = torch.concat(pred_logits, y_hat, dim=0)
            pred_labels = torch.concat(pred_labels, y_hat.argmax(axis=1), dim=0)

    return pred_logits.numpy(), pred_labels.numpy()

# Função para inicializar pesos da rede
def weights_init(m):
    if type(m) == nn.Linear:
        m.weight.data.normal_(0.0, 0.01) # valores iniciais são uma normal
        m.bias.data.fill_(0)

# %% [markdown]
# # Problema 1
#
# Neste problema, você receberá 14 *features* coletadas de pacientes e tentará predizer se eles tem algum sinal de doença cardíaca. Mais sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/Heart+Disease

# %%
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data
data = np.genfromtxt('processed.cleveland.data', delimiter=',', dtype=np.float32)
data = np.nan_to_num(data)

print(data.shape, data[0, :])
X, y = data[:, :-1], data[:, -1]
print(X.shape, X[0, :])
print(y.shape, y[0])
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.20, random_state=42)
  
batch_size = 100
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)
# Out:
# (303, 14) [ 63.    1.    1.  145.  233.    1.    2.  150.    0.    2.3   3.    0.
#    6.    0. ]
# (303, 13) [ 63.    1.    1.  145.  233.    1.    2.  150.    0.    2.3   3.    0.
#    6. ]
# (303,) 0.0

# %%
batch_size, epochs, lr, weight_decay = 10, 25, 0.0001, 0.1

net = nn.Sequential(nn.Linear(13, 512), 
                    nn.ReLU(),
                    nn.Dropout(0.25),
                    nn.Linear(512, 256),
                    nn.ReLU(),
                    nn.Dropout(0.5),
                    nn.Linear(256, 128),
                    nn.ReLU(),
                    nn.Linear(128, 64),
                    nn.ReLU(),
                    nn.Linear(64, 5))


net.apply(weights_init)
net.to(device)

loss = nn.CrossEntropyLoss().to(device)
trainer = torch.optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay)

train_validate(net, train_iter, test_iter, batch_size, trainer, loss, epochs, 'classification')
# Out:
# training on cpu
# epoch 1, train loss 1.6095, train acc 0.136, test loss 1.6095, test acc 0.066, time 0.0 sec
# epoch 2, train loss 1.6094, train acc 0.202, test loss 1.6095, test acc 0.066, time 0.0 sec
# epoch 3, train loss 1.6094, train acc 0.190, test loss 1.6094, test acc 0.066, time 0.0 sec
# epoch 4, train loss 1.6094, train acc 0.285, test loss 1.6094, test acc 0.230, time 0.0 sec
# epoch 5, train loss 1.6093, train acc 0.322, test loss 1.6093, test acc 0.426, time 0.0 sec
# epoch 6, train loss 1.6093, train acc 0.393, test loss 1.6093, test acc 0.459, time 0.0 sec
# epoch 7, train loss 1.6092, train acc 0.401, test loss 1.6093, test acc 0.459, time 0.0 sec
# epoch 8, train loss 1.6092, train acc 0.467, test loss 1.6092, test acc 0.475, time 0.0 sec
# epoch 9, train loss 1.6092, train acc 0.479, test loss 1.6092, test acc 0.475, time 0.0 sec
# epoch 10, train loss 1.6090, train acc 0.521, test loss 1.6092, test acc 0.475, time 0.0 sec
# epoch 11, train loss 1.6090, train acc 0.537, test loss 1.6091, test acc 0.475, time 0.0 sec
# epoch 12, train loss 1.6090, train acc 0.533, test loss 1.6091, test acc 0.475, time 0.0 sec
# epoch 13, train loss 1.6089, train acc 0.550, test loss 1.6090, test acc 0.475, time 0.0 sec
# epoch 14, train loss 1.6089, train acc 0.541, test loss 1.6090, test acc 0.475, time 0.0 sec
# epoch 15, train loss 1.6088, train acc 0.554, test loss 1.6090, test acc 0.475, time 0.0 sec
# epoch 16, train loss 1.6088, train acc 0.558, test loss 1.6089, test acc 0.475, time 0.0 sec
# epoch 17, train loss 1.6087, train acc 0.562, test loss 1.6089, test acc 0.475, time 0.0 sec
# epoch 18, train loss 1.6086, train acc 0.558, test loss 1.6088, test acc 0.475, time 0.0 sec
# epoch 19, train loss 1.6086, train acc 0.558, test loss 1.6088, test acc 0.475, time 0.0 sec
# epoch 20, train loss 1.6086, train acc 0.558, test loss 1.6088, test acc 0.475, time 0.0 sec
# epoch 21, train loss 1.6085, train acc 0.558, test loss 1.6087, test acc 0.475, time 0.0 sec
# epoch 22, train loss 1.6085, train acc 0.558, test loss 1.6087, test acc 0.475, time 0.0 sec
# epoch 23, train loss 1.6084, train acc 0.558, test loss 1.6086, test acc 0.475, time 0.0 sec
# epoch 24, train loss 1.6084, train acc 0.558, test loss 1.6086, test acc 0.475, time 0.0 sec
# epoch 25, train loss 1.6083, train acc 0.558, test loss 1.6086, test acc 0.475, time 0.0 sec

# %% [markdown]
# # Problema 2
#
# Neste problema, você receberá 90 *features* extraídas de diversas músicas (datadas de 1922 até 2011) e deve predizer o ano de cada música. Mais sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/YearPredictionMSD

# %%
# download do dataset
#!wget http://archive.ics.uci.edu/ml/machine-learning-databases/00203/YearPredictionMSD.txt.zip
#!unzip YearPredictionMSD.txt.zip
data = np.genfromtxt('YearPredictionMSD.txt', delimiter=',', dtype=np.float32)

print(data[0, :])
X, y = data[:, 1:], data[:, 0]
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.33, random_state=42)
  
batch_size = 100
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)
# Out:
# [ 2.0010000e+03  4.9943569e+01  2.1471140e+01  7.3077499e+01
#   8.7486095e+00 -1.7406281e+01 -1.3099050e+01 -2.5012020e+01
#  -1.2232570e+01  7.8308902e+00 -2.4678299e+00  3.3213601e+00
#  -2.3152101e+00  1.0205560e+01  6.1110913e+02  9.5108960e+02
#   6.9811426e+02  4.0898486e+02  3.8370911e+02  3.2651511e+02
#   2.3811327e+02  2.5142413e+02  1.8717351e+02  1.0042652e+02
#   1.7919498e+02 -8.4155798e+00 -3.1787039e+02  9.5862663e+01
#   4.8102589e+01 -9.5663033e+01 -1.8062149e+01  1.9698400e+00
#   3.4424381e+01  1.1726700e+01  1.3679000e+00  7.7944398e+00
#  -3.6994001e-01 -1.3367851e+02 -8.3261650e+01 -3.7297649e+01
#   7.3046669e+01 -3.7366840e+01 -3.1385300e+00 -2.4215309e+01
#  -1.3230660e+01  1.5938090e+01 -1.8604780e+01  8.2154793e+01
#   2.4057980e+02 -1.0294070e+01  3.1584311e+01 -2.5381870e+01
#  -3.9077201e+00  1.3292580e+01  4.1550598e+01 -7.2627201e+00
#  -2.1008631e+01  1.0550848e+02  6.4298561e+01  2.6084810e+01
#  -4.4591099e+01 -8.3065701e+00  7.9370599e+00 -1.0736600e+01
#  -9.5447662e+01 -8.2033073e+01 -3.5591942e+01  4.6952500e+00
#   7.0956261e+01  2.8091391e+01  6.0201502e+00 -3.7137669e+01
#  -4.1124500e+01 -8.4081602e+00  7.1987700e+00 -8.6017599e+00
#  -5.9085698e+00 -1.2324370e+01  1.4687340e+01 -5.4321251e+01
#   4.0147861e+01  1.3016200e+01 -5.4405479e+01  5.8993671e+01
#   1.5373440e+01  1.1114399e+00 -2.3087931e+01  6.8407951e+01
#  -1.8222300e+00 -2.7463480e+01  2.2632699e+00]

# %%
epochs, lr, weitght_decay = 400, 0.0001, 0.0000001

net = nn.Sequential(nn.Linear(90, 128),
                    nn.ReLU(),
                    nn.Linear(128, 256),
                    nn.ReLU(),
                    nn.Linear(256, 1))

net.apply(weights_init)
net.to(device)

loss = nn.SmoothL1Loss().to(device)

trainer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)

train_validate(net, train_iter, test_iter, batch_size, trainer, loss, epochs)
# Out:
# training on cpu
# /Users/danielcarmo/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/loss.py:928: UserWarning: Using a target size (torch.Size([100])) that is different to the input size (torch.Size([100, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
# /Users/danielcarmo/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/loss.py:928: UserWarning: Using a target size (torch.Size([81])) that is different to the input size (torch.Size([81, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
# /Users/danielcarmo/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/loss.py:928: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
# epoch 1, train loss 381.5955, test loss 169.7589, time 4.9 sec
# epoch 2, train loss 137.0310, test loss 115.7180, time 4.8 sec
# epoch 3, train loss 105.7628, test loss 99.6134, time 4.8 sec
# epoch 4, train loss 98.0318, test loss 96.3751, time 4.8 sec
# epoch 5, train loss 95.6785, test loss 94.9139, time 4.7 sec
# epoch 6, train loss 94.1506, test loss 107.5833, time 4.7 sec
# epoch 7, train loss 92.9504, test loss 91.6857, time 4.7 sec
# epoch 8, train loss 91.9238, test loss 91.2163, time 4.8 sec
# epoch 9, train loss 91.3622, test loss 89.1317, time 4.9 sec
# epoch 10, train loss 90.6620, test loss 89.2406, time 5.0 sec
# epoch 11, train loss 90.0917, test loss 88.6142, time 4.9 sec
# epoch 12, train loss 89.6248, test loss 87.7521, time 4.8 sec
# epoch 13, train loss 89.0940, test loss 86.7760, time 4.8 sec
# epoch 14, train loss 88.7468, test loss 90.2669, time 4.9 sec
# epoch 15, train loss 88.3741, test loss 89.2062, time 4.9 sec
# epoch 16, train loss 87.9793, test loss 91.6440, time 4.8 sec
# epoch 17, train loss 87.7434, test loss 89.3324, time 4.9 sec
# epoch 18, train loss 87.2438, test loss 86.0787, time 4.8 sec
# epoch 19, train loss 87.0379, test loss 89.6414, time 5.0 sec
# epoch 20, train loss 86.7041, test loss 85.2012, time 4.9 sec
# epoch 21, train loss 86.4159, test loss 93.1156, time 4.9 sec
# epoch 22, train loss 86.2880, test loss 87.4667, time 5.1 sec
# epoch 23, train loss 85.8824, test loss 84.6085, time 4.9 sec
# epoch 24, train loss 85.7119, test loss 87.6881, time 5.0 sec
# epoch 25, train loss 85.3806, test loss 86.5047, time 4.9 sec
# epoch 26, train loss 85.0010, test loss 84.0776, time 4.9 sec
# epoch 27, train loss 84.9614, test loss 83.8460, time 4.9 sec
# epoch 28, train loss 84.8125, test loss 88.4032, time 4.9 sec
# epoch 29, train loss 84.7473, test loss 84.4040, time 4.8 sec
# epoch 30, train loss 84.3978, test loss 82.7031, time 5.0 sec
# epoch 31, train loss 84.2317, test loss 84.2938, time 5.0 sec
# epoch 32, train loss 84.1628, test loss 87.3070, time 4.9 sec
# epoch 33, train loss 83.9642, test loss 84.7252, time 5.1 sec
# epoch 34, train loss 83.8402, test loss 84.2559, time 5.2 sec
# epoch 35, train loss 83.6722, test loss 82.3655, time 5.2 sec
# epoch 36, train loss 83.3860, test loss 82.5687, time 5.1 sec
# epoch 37, train loss 83.4513, test loss 83.6814, time 5.0 sec
# epoch 38, train loss 82.9515, test loss 81.9318, time 5.0 sec
# epoch 39, train loss 83.0197, test loss 82.1954, time 5.1 sec
# epoch 40, train loss 82.8043, test loss 83.9177, time 5.1 sec
# epoch 41, train loss 82.7138, test loss 81.6849, time 5.1 sec
# epoch 42, train loss 82.7041, test loss 83.5037, time 5.0 sec
# epoch 43, train loss 82.4962, test loss 83.2052, time 5.0 sec
# epoch 44, train loss 82.3549, test loss 82.1514, time 5.0 sec
# epoch 45, train loss 82.2011, test loss 84.6118, time 5.0 sec
# epoch 46, train loss 82.0299, test loss 81.7143, time 5.0 sec
# epoch 47, train loss 81.9370, test loss 81.6404, time 5.0 sec
# epoch 48, train loss 81.8446, test loss 81.8943, time 5.0 sec
# epoch 49, train loss 81.6841, test loss 81.4853, time 5.0 sec
# epoch 50, train loss 81.5952, test loss 89.1522, time 5.2 sec
# epoch 51, train loss 81.1875, test loss 80.7924, time 5.0 sec
# epoch 52, train loss 81.2452, test loss 81.8894, time 5.0 sec
# epoch 53, train loss 81.0072, test loss 80.5730, time 4.9 sec
# epoch 54, train loss 80.9032, test loss 80.6283, time 5.0 sec
# epoch 55, train loss 80.7988, test loss 81.2736, time 5.0 sec
# epoch 56, train loss 80.6624, test loss 79.7424, time 5.0 sec
# epoch 57, train loss 80.5596, test loss 86.7234, time 4.8 sec
# epoch 58, train loss 80.4372, test loss 84.1872, time 4.9 sec
# epoch 59, train loss 80.3705, test loss 79.8241, time 4.8 sec
# epoch 60, train loss 80.2509, test loss 80.5539, time 5.0 sec
# epoch 61, train loss 80.3210, test loss 79.8290, time 5.0 sec
# epoch 62, train loss 80.1155, test loss 82.6348, time 5.1 sec
# epoch 63, train loss 80.0456, test loss 84.2260, time 5.0 sec
# epoch 64, train loss 79.7361, test loss 79.6689, time 4.9 sec
# epoch 65, train loss 79.8553, test loss 80.4319, time 4.9 sec
# epoch 66, train loss 79.7504, test loss 79.4508, time 4.9 sec
# epoch 67, train loss 79.6924, test loss 80.5372, time 5.0 sec
# epoch 68, train loss 79.5055, test loss 80.7271, time 5.0 sec
# epoch 69, train loss 79.4112, test loss 83.6938, time 5.0 sec
# epoch 70, train loss 79.4055, test loss 79.2933, time 4.9 sec
# epoch 71, train loss 79.2587, test loss 79.1874, time 4.9 sec
# epoch 72, train loss 79.2203, test loss 82.6594, time 4.8 sec
# epoch 73, train loss 79.1326, test loss 81.4562, time 4.9 sec
# epoch 74, train loss 78.9993, test loss 80.1521, time 5.0 sec
# epoch 75, train loss 79.0450, test loss 77.9952, time 4.9 sec
# epoch 76, train loss 78.8448, test loss 78.3089, time 5.0 sec
# epoch 77, train loss 78.7315, test loss 78.3970, time 4.9 sec
# epoch 78, train loss 78.7605, test loss 81.1501, time 4.9 sec
# epoch 79, train loss 78.6722, test loss 81.7672, time 5.0 sec
# epoch 80, train loss 78.7827, test loss 78.8451, time 4.8 sec
# epoch 81, train loss 78.5676, test loss 81.0272, time 4.8 sec
# epoch 82, train loss 78.4716, test loss 79.5684, time 5.0 sec
# epoch 83, train loss 78.5211, test loss 78.1926, time 5.0 sec
# epoch 84, train loss 78.4029, test loss 79.5520, time 5.1 sec
# epoch 85, train loss 78.2816, test loss 77.9302, time 5.0 sec
# epoch 86, train loss 78.2921, test loss 78.5469, time 5.0 sec
# epoch 87, train loss 78.2249, test loss 78.9569, time 5.0 sec
# epoch 88, train loss 78.2167, test loss 79.1364, time 5.0 sec
# epoch 89, train loss 78.0268, test loss 79.2262, time 4.9 sec
# epoch 90, train loss 78.0099, test loss 84.9415, time 5.0 sec
# epoch 182, train loss 75.6507, test loss 76.9311, time 4.9 sec
# epoch 183, train loss 75.6425, test loss 77.2312, time 4.9 sec
# epoch 184, train loss 75.5565, test loss 79.4468, time 4.9 sec
# epoch 185, train loss 75.6439, test loss 77.8742, time 4.9 sec
# epoch 186, train loss 75.6936, test loss 76.3439, time 5.0 sec
# epoch 187, train loss 75.5420, test loss 76.6281, time 4.9 sec
# epoch 188, train loss 75.5439, test loss 76.4320, time 4.9 sec
# epoch 189, train loss 75.4951, test loss 76.8533, time 4.8 sec
# epoch 190, train loss 75.4479, test loss 78.5500, time 4.8 sec
# epoch 191, train loss 75.5327, test loss 76.7785, time 4.9 sec
# epoch 192, train loss 75.5820, test loss 76.2905, time 4.9 sec
# epoch 193, train loss 75.5254, test loss 77.2247, time 5.0 sec
# epoch 194, train loss 75.4022, test loss 77.1526, time 5.0 sec
# epoch 195, train loss 75.4097, test loss 77.1809, time 5.0 sec
# epoch 196, train loss 75.3174, test loss 77.8117, time 5.0 sec
# epoch 197, train loss 75.5143, test loss 76.8489, time 4.9 sec
# epoch 198, train loss 75.3707, test loss 76.3494, time 4.9 sec
# epoch 199, train loss 75.2422, test loss 76.6896, time 4.9 sec
# epoch 200, train loss 75.4820, test loss 79.8544, time 4.8 sec
# epoch 201, train loss 75.3943, test loss 76.3886, time 4.8 sec
# epoch 202, train loss 75.2690, test loss 76.5281, time 4.8 sec
# epoch 203, train loss 75.2912, test loss 76.0578, time 4.8 sec
# epoch 204, train loss 75.2349, test loss 76.4588, time 4.9 sec
# epoch 205, train loss 75.2032, test loss 81.2515, time 4.9 sec
# epoch 206, train loss 75.2533, test loss 76.4752, time 4.9 sec
# epoch 207, train loss 75.3241, test loss 77.6486, time 4.9 sec
# epoch 208, train loss 75.1478, test loss 76.4807, time 5.0 sec
# epoch 209, train loss 75.3087, test loss 78.7875, time 4.9 sec
# epoch 210, train loss 75.1364, test loss 76.2970, time 5.0 sec
# epoch 211, train loss 75.2190, test loss 75.8598, time 5.0 sec
# epoch 212, train loss 75.1519, test loss 75.9336, time 4.9 sec
# epoch 213, train loss 75.1447, test loss 76.5354, time 5.0 sec
# epoch 214, train loss 75.1872, test loss 76.0738, time 5.0 sec
# epoch 215, train loss 75.1188, test loss 77.6140, time 4.9 sec
# epoch 216, train loss 75.0670, test loss 76.5058, time 4.9 sec
# epoch 217, train loss 75.2501, test loss 76.2164, time 5.0 sec
# epoch 218, train loss 75.0466, test loss 76.7882, time 4.6 sec
# epoch 219, train loss 75.0096, test loss 78.3671, time 4.9 sec
# epoch 220, train loss 75.0720, test loss 76.3435, time 4.9 sec
# epoch 221, train loss 75.0770, test loss 75.7019, time 5.1 sec
# epoch 222, train loss 75.0132, test loss 76.9153, time 4.9 sec
# epoch 223, train loss 75.0368, test loss 77.8071, time 5.0 sec
# epoch 224, train loss 75.0579, test loss 79.1173, time 4.9 sec
# epoch 225, train loss 74.9898, test loss 76.4596, time 4.9 sec
# epoch 226, train loss 75.0035, test loss 76.8260, time 4.9 sec
# epoch 272, train loss 74.4477, test loss 76.8363, time 5.0 sec
# epoch 273, train loss 74.5541, test loss 76.1050, time 5.0 sec
# epoch 274, train loss 74.4402, test loss 75.8176, time 5.0 sec
# epoch 275, train loss 74.5162, test loss 75.6670, time 5.0 sec
# epoch 276, train loss 74.5087, test loss 78.4041, time 5.0 sec
# epoch 277, train loss 74.4790, test loss 76.8068, time 5.0 sec
# epoch 278, train loss 74.4284, test loss 77.1172, time 5.0 sec
# epoch 279, train loss 74.5037, test loss 78.2226, time 4.9 sec
# epoch 280, train loss 74.5316, test loss 78.2574, time 4.9 sec
# epoch 281, train loss 74.5685, test loss 75.8589, time 4.9 sec
# epoch 282, train loss 74.4779, test loss 76.0856, time 4.9 sec
# epoch 283, train loss 74.3397, test loss 77.9392, time 5.0 sec
# epoch 284, train loss 74.3926, test loss 75.8700, time 4.9 sec
# epoch 285, train loss 74.3801, test loss 76.6668, time 5.0 sec
# epoch 286, train loss 74.5074, test loss 76.0512, time 4.9 sec
# epoch 287, train loss 74.3236, test loss 75.3711, time 5.0 sec
# epoch 288, train loss 74.3611, test loss 76.6357, time 5.0 sec
# epoch 289, train loss 74.4447, test loss 75.4781, time 4.9 sec
# epoch 290, train loss 74.2518, test loss 76.1657, time 4.9 sec
# epoch 291, train loss 74.4541, test loss 76.3999, time 5.0 sec
# epoch 292, train loss 74.3408, test loss 79.0721, time 5.0 sec
# epoch 293, train loss 74.3140, test loss 76.7246, time 4.9 sec
# epoch 294, train loss 74.3755, test loss 75.3666, time 4.9 sec
# epoch 295, train loss 74.3580, test loss 75.9161, time 4.8 sec
# epoch 296, train loss 74.4932, test loss 77.3873, time 4.9 sec
# epoch 297, train loss 74.3305, test loss 76.0675, time 4.9 sec
# epoch 298, train loss 74.2673, test loss 75.8750, time 4.9 sec
# epoch 299, train loss 74.3887, test loss 76.2027, time 4.9 sec
# epoch 300, train loss 74.4073, test loss 75.8638, time 4.9 sec
# epoch 301, train loss 74.3673, test loss 76.0632, time 4.8 sec
# epoch 302, train loss 74.2204, test loss 79.2298, time 4.8 sec
# epoch 303, train loss 74.3059, test loss 76.3841, time 4.8 sec
# epoch 304, train loss 74.3620, test loss 77.1419, time 4.9 sec
# epoch 305, train loss 74.2875, test loss 75.6728, time 4.9 sec
# epoch 306, train loss 74.1840, test loss 75.9840, time 4.9 sec
# epoch 307, train loss 74.3414, test loss 75.5676, time 4.8 sec
# epoch 308, train loss 74.1921, test loss 75.1294, time 4.9 sec
# epoch 309, train loss 74.2184, test loss 75.8427, time 5.1 sec
# epoch 310, train loss 74.2870, test loss 75.5158, time 5.1 sec
# epoch 311, train loss 74.1324, test loss 76.2007, time 5.0 sec
# epoch 312, train loss 74.2577, test loss 76.1212, time 5.0 sec
# epoch 313, train loss 74.2908, test loss 76.2218, time 4.9 sec
# epoch 314, train loss 74.1885, test loss 78.1260, time 4.9 sec
# epoch 315, train loss 74.2201, test loss 79.2451, time 4.8 sec
# epoch 316, train loss 74.1151, test loss 75.9269, time 4.9 sec
# epoch 317, train loss 74.2294, test loss 76.8509, time 5.0 sec
# epoch 318, train loss 74.1533, test loss 75.4225, time 4.9 sec
# epoch 319, train loss 74.2277, test loss 75.9517, time 4.9 sec
# epoch 320, train loss 74.1192, test loss 75.9647, time 4.9 sec
# epoch 321, train loss 74.1661, test loss 75.4593, time 4.9 sec
# epoch 322, train loss 74.1719, test loss 77.3065, time 5.1 sec
# epoch 323, train loss 74.0979, test loss 75.3293, time 5.0 sec
# epoch 324, train loss 74.2348, test loss 75.6826, time 4.9 sec
# epoch 325, train loss 74.2438, test loss 75.2385, time 4.8 sec
# epoch 326, train loss 74.1826, test loss 76.0799, time 4.9 sec
# epoch 327, train loss 74.2056, test loss 80.6390, time 5.0 sec
# epoch 328, train loss 74.2358, test loss 75.3039, time 4.9 sec
# epoch 329, train loss 74.1868, test loss 76.5804, time 5.0 sec
# epoch 330, train loss 74.1027, test loss 75.9727, time 4.9 sec
# epoch 331, train loss 74.1051, test loss 76.0101, time 4.6 sec
# epoch 332, train loss 74.0899, test loss 79.4004, time 4.8 sec
# epoch 333, train loss 74.1833, test loss 76.6170, time 4.8 sec
# epoch 334, train loss 74.2050, test loss 75.1309, time 4.9 sec
# epoch 335, train loss 74.0939, test loss 81.4936, time 4.9 sec
# epoch 336, train loss 74.0418, test loss 75.8016, time 4.7 sec
# epoch 337, train loss 74.0755, test loss 76.1701, time 4.8 sec
# epoch 338, train loss 74.1140, test loss 78.7207, time 4.7 sec
# epoch 339, train loss 74.0775, test loss 75.1243, time 4.8 sec
# epoch 340, train loss 74.1424, test loss 75.9775, time 4.8 sec
# epoch 341, train loss 74.1510, test loss 78.0493, time 4.9 sec
# epoch 342, train loss 74.0123, test loss 75.9653, time 4.9 sec
# epoch 343, train loss 74.2065, test loss 76.1119, time 4.9 sec
# epoch 344, train loss 74.1310, test loss 77.1817, time 4.9 sec
# epoch 345, train loss 73.9458, test loss 76.9716, time 4.8 sec
# epoch 346, train loss 74.1556, test loss 75.0993, time 4.7 sec
# epoch 347, train loss 74.0804, test loss 75.7836, time 4.8 sec
# epoch 348, train loss 74.0017, test loss 77.2770, time 4.9 sec
# epoch 349, train loss 74.1072, test loss 76.2627, time 5.0 sec
# epoch 350, train loss 74.1084, test loss 75.8738, time 5.0 sec
# epoch 351, train loss 74.1186, test loss 75.7648, time 5.0 sec
# epoch 352, train loss 74.1245, test loss 76.6994, time 4.6 sec
# epoch 353, train loss 73.9415, test loss 76.0159, time 5.0 sec
# epoch 354, train loss 74.0359, test loss 75.5851, time 4.9 sec
# epoch 355, train loss 74.0769, test loss 75.7049, time 4.9 sec
# epoch 356, train loss 74.0610, test loss 76.0164, time 5.0 sec
# epoch 357, train loss 73.9958, test loss 76.0413, time 4.9 sec
# epoch 358, train loss 74.0746, test loss 75.8020, time 4.7 sec
# epoch 359, train loss 74.1377, test loss 78.2269, time 4.9 sec
# epoch 360, train loss 74.0371, test loss 76.4935, time 4.9 sec
# epoch 361, train loss 74.0055, test loss 76.8191, time 4.8 sec
# epoch 362, train loss 74.0249, test loss 75.6032, time 4.9 sec
# epoch 363, train loss 74.0659, test loss 76.3625, time 4.8 sec
# epoch 364, train loss 74.1359, test loss 75.9896, time 4.8 sec
# epoch 365, train loss 74.1163, test loss 75.8175, time 4.8 sec
# epoch 366, train loss 73.9976, test loss 75.7765, time 4.8 sec
# epoch 367, train loss 74.0093, test loss 79.7621, time 4.8 sec
# epoch 368, train loss 73.9815, test loss 75.3564, time 5.0 sec
# epoch 369, train loss 74.0440, test loss 76.4155, time 4.8 sec
# epoch 370, train loss 74.0230, test loss 76.7639, time 4.9 sec
# epoch 371, train loss 73.9810, test loss 78.7915, time 4.9 sec
# epoch 372, train loss 74.0268, test loss 77.8817, time 4.9 sec
# epoch 373, train loss 73.9893, test loss 75.1790, time 4.9 sec
# epoch 374, train loss 73.8946, test loss 76.5873, time 4.8 sec
# epoch 375, train loss 73.9537, test loss 76.8177, time 4.9 sec
# epoch 376, train loss 74.0518, test loss 75.2008, time 4.9 sec
# epoch 377, train loss 74.0667, test loss 76.6775, time 5.0 sec
# epoch 378, train loss 74.0047, test loss 76.2488, time 5.0 sec
# epoch 379, train loss 73.9808, test loss 75.2445, time 4.6 sec
# epoch 380, train loss 73.9260, test loss 75.6922, time 5.0 sec
# epoch 381, train loss 73.8832, test loss 76.0176, time 4.9 sec
# epoch 382, train loss 73.9890, test loss 78.2389, time 4.9 sec
# epoch 383, train loss 73.9520, test loss 75.7762, time 4.9 sec
# epoch 384, train loss 74.0104, test loss 75.9936, time 4.9 sec
# epoch 385, train loss 73.9750, test loss 75.7220, time 5.0 sec
# epoch 386, train loss 73.9137, test loss 75.7394, time 5.0 sec
# epoch 387, train loss 74.0397, test loss 76.1730, time 4.9 sec
# epoch 388, train loss 73.9199, test loss 76.0669, time 4.8 sec
# epoch 389, train loss 73.8793, test loss 76.6583, time 4.9 sec
# epoch 390, train loss 73.9762, test loss 75.8026, time 5.0 sec
# epoch 391, train loss 73.9270, test loss 75.4838, time 5.0 sec
# epoch 392, train loss 73.9017, test loss 75.2438, time 4.9 sec
# epoch 393, train loss 73.9530, test loss 75.1902, time 4.9 sec
# epoch 394, train loss 73.8209, test loss 80.0914, time 4.8 sec
# epoch 395, train loss 73.9110, test loss 75.5340, time 5.0 sec
# epoch 396, train loss 73.8433, test loss 75.3763, time 5.0 sec
# epoch 397, train loss 73.9981, test loss 76.7608, time 4.7 sec
# epoch 398, train loss 73.8107, test loss 75.9162, time 5.0 sec
# epoch 399, train loss 73.8687, test loss 75.0754, time 5.0 sec
# epoch 400, train loss 73.8392, test loss 75.8282, time 5.1 sec

# %%
# mostra o resultado predito para as 5 primeiras instâncias de teste
y = net(torch.Tensor(test_features[0:5, :]).to(device))
print(y, test_labels[0:5])
# Out:
# tensor([[2119.0874],
#         [2008.2554],
#         [2067.5142],
#         [1765.3359],
#         [1925.9906]], grad_fn=<AddmmBackward0>) [2008. 2001. 2006. 2008. 1998.]

# %% [markdown]
# O resultado está ok, considerando que computamos tais valores localmente. Seriam necessárias mais épocas para conseguirmos uma acurácia maior.

# %% [markdown]
# # Problema 3
#
# Neste problema, você receberá várias *features* (como altura média, inclinação, etc) descrevendo uma região e o modelo deve predizer qual o tipo da região (floresta, montanha, etc). Mais informações sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/covertype

# %%
#!wget http://archive.ics.uci.edu/ml/machine-learning-databases/covtype/covtype.data.gz
#!gzip covtype.data.gz
data = np.genfromtxt('covtype.data', delimiter=',', dtype=np.float32)

print(data.shape, data[0, :])
X, y = data[:, :-1], data[:, -1]
print(X.shape, X[0, :])
print(y.shape, y[0])
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.33, random_state=42)
train_labels = train_labels - 1
test_labels = test_labels - 1
  
batch_size = 100
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)
# Out:
# (581012, 55) [2.596e+03 5.100e+01 3.000e+00 2.580e+02 0.000e+00 5.100e+02 2.210e+02
#  2.320e+02 1.480e+02 6.279e+03 1.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  1.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 5.000e+00]
# (581012, 54) [2.596e+03 5.100e+01 3.000e+00 2.580e+02 0.000e+00 5.100e+02 2.210e+02
#  2.320e+02 1.480e+02 6.279e+03 1.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  1.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# (581012,) 5.0

# %%
epochs, lr, weight_decay = 20, 0.001, 0.0001

net = nn.Sequential(nn.Linear(54, 128),
                    nn.ReLU(),
                    nn.Dropout(0.25),
                    nn.Linear(128, 256),
                    nn.ReLU(),
                    nn.Dropout(0.5),
                    nn.Linear(256, 7))

net.apply(weights_init)
net.to(device)

loss = nn.CrossEntropyLoss().to(device)

trainer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)

train_validate(net, train_iter, test_iter, batch_size, trainer, loss, epochs, 'classification')
# Out:
# training on cpu
# epoch 1, train loss 0.8852, train acc 0.622, test loss 0.8169, test acc 0.670, time 7.5 sec
# epoch 2, train loss 0.8860, train acc 0.638, test loss 0.8178, test acc 0.681, time 7.5 sec
# epoch 3, train loss 0.8727, train acc 0.647, test loss 0.8728, test acc 0.627, time 7.4 sec
# epoch 4, train loss 0.8611, train acc 0.653, test loss 0.8355, test acc 0.671, time 7.4 sec
# epoch 5, train loss 0.8580, train acc 0.653, test loss 0.7985, test acc 0.674, time 7.4 sec
# epoch 6, train loss 0.8514, train acc 0.655, test loss 0.8335, test acc 0.671, time 7.4 sec
# epoch 7, train loss 0.8470, train acc 0.658, test loss 0.8024, test acc 0.679, time 7.4 sec
# epoch 8, train loss 0.8524, train acc 0.653, test loss 0.8032, test acc 0.672, time 7.5 sec
# epoch 9, train loss 0.8501, train acc 0.654, test loss 0.8207, test acc 0.644, time 7.4 sec
# epoch 10, train loss 0.8481, train acc 0.655, test loss 0.8476, test acc 0.626, time 7.5 sec
# epoch 11, train loss 0.8481, train acc 0.654, test loss 0.8748, test acc 0.637, time 7.5 sec
# epoch 12, train loss 0.8465, train acc 0.655, test loss 0.7959, test acc 0.665, time 7.5 sec
# epoch 13, train loss 0.8429, train acc 0.657, test loss 0.8590, test acc 0.672, time 7.6 sec
# epoch 14, train loss 0.8422, train acc 0.656, test loss 0.8521, test acc 0.658, time 7.5 sec
# epoch 15, train loss 0.8398, train acc 0.658, test loss 0.8276, test acc 0.671, time 7.4 sec
# epoch 16, train loss 0.8394, train acc 0.658, test loss 0.7847, test acc 0.686, time 7.2 sec
# epoch 17, train loss 0.8376, train acc 0.659, test loss 0.8382, test acc 0.647, time 7.4 sec
# epoch 18, train loss 0.8328, train acc 0.660, test loss 0.8405, test acc 0.672, time 7.4 sec
# epoch 19, train loss 0.8274, train acc 0.662, test loss 0.9061, test acc 0.630, time 7.4 sec
# epoch 20, train loss 0.8248, train acc 0.664, test loss 0.7923, test acc 0.672, time 7.4 sec

# %% [markdown]
# # Problema 4
#
# Neste problema, você receberá 11 *features* extraídas de tipos de vinhos, e terá que predizer um *score* para cada vinho. Mais sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/Wine+Quality

# %%
# download do dataset
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
data_red = np.genfromtxt('winequality-red.csv', delimiter=';', dtype=np.float32, skip_header=1)
data_white = np.genfromtxt('winequality-white.csv', delimiter=';', dtype=np.float32, skip_header=1)
data = np.concatenate((data_red, data_white), axis=0)
data = np.nan_to_num(data)

print(data[0, :])
X, y = data[:, :-1], data[:, -1]
print(X.shape, y.shape)
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.33, random_state=42)

batch_size = 100
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)
# Out:
# [ 7.4     0.7     0.      1.9     0.076  11.     34.      0.9978  3.51
#   0.56    9.4     5.    ]
# (6497, 11) (6497,)

# %%
epochs, lr, weight_decay = 100, 0.0001, 0.0001

net = nn.Sequential(nn.Linear(11, 128),
                    nn.ReLU(),
                    nn.Dropout(0.25),
                    nn.Linear(128, 256),
                    nn.ReLU(),
                    nn.Dropout(0.5),
                    nn.Linear(256, 128),
                    nn.ReLU(),
                    nn.Linear(128, 1))

net.apply(weights_init)
net.to(device)

loss = nn.SmoothL1Loss().to(device)

trainer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)

train_validate(net, train_iter, test_iter, batch_size, trainer, loss, epochs)
# Out:
# training on cpu
# epoch 1, train loss 5.2175, test loss 4.8701, time 0.1 sec
# epoch 2, train loss 2.9656, test loss 1.5894, time 0.1 sec
# epoch 3, train loss 1.4268, test loss 1.2943, time 0.1 sec
# epoch 4, train loss 1.2213, test loss 1.0835, time 0.1 sec
# epoch 5, train loss 0.9777, test loss 0.7426, time 0.1 sec
# epoch 6, train loss 0.6518, test loss 0.4079, time 0.1 sec
# epoch 7, train loss 0.4948, test loss 0.3782, time 0.1 sec
# epoch 8, train loss 0.4817, test loss 0.3728, time 0.1 sec
# epoch 9, train loss 0.4752, test loss 0.3721, time 0.1 sec
# epoch 10, train loss 0.4776, test loss 0.3704, time 0.1 sec
# epoch 11, train loss 0.4829, test loss 0.3720, time 0.1 sec
# epoch 12, train loss 0.4752, test loss 0.3698, time 0.1 sec
# epoch 13, train loss 0.4732, test loss 0.3679, time 0.1 sec
# epoch 14, train loss 0.4714, test loss 0.3699, time 0.1 sec
# epoch 60, train loss 0.4375, test loss 0.3472, time 0.1 sec
# epoch 61, train loss 0.4415, test loss 0.3493, time 0.1 sec
# epoch 62, train loss 0.4387, test loss 0.3497, time 0.1 sec
# epoch 63, train loss 0.4491, test loss 0.3511, time 0.1 sec
# epoch 64, train loss 0.4417, test loss 0.3459, time 0.1 sec
# epoch 65, train loss 0.4365, test loss 0.3481, time 0.1 sec
# epoch 66, train loss 0.4367, test loss 0.3454, time 0.1 sec
# epoch 67, train loss 0.4378, test loss 0.3455, time 0.1 sec
# epoch 68, train loss 0.4425, test loss 0.3549, time 0.1 sec
# epoch 69, train loss 0.4378, test loss 0.3495, time 0.1 sec
# epoch 70, train loss 0.4349, test loss 0.3443, time 0.1 sec
# epoch 71, train loss 0.4385, test loss 0.3544, time 0.1 sec
# epoch 72, train loss 0.4443, test loss 0.3448, time 0.1 sec
# epoch 73, train loss 0.4346, test loss 0.3470, time 0.1 sec
# epoch 74, train loss 0.4315, test loss 0.3434, time 0.1 sec
# epoch 75, train loss 0.4360, test loss 0.3465, time 0.1 sec
# epoch 76, train loss 0.4367, test loss 0.3449, time 0.1 sec
# epoch 77, train loss 0.4333, test loss 0.3425, time 0.1 sec
# epoch 78, train loss 0.4417, test loss 0.3427, time 0.1 sec
# epoch 79, train loss 0.4323, test loss 0.3422, time 0.1 sec
# epoch 80, train loss 0.4334, test loss 0.3418, time 0.1 sec
# epoch 81, train loss 0.4342, test loss 0.3433, time 0.1 sec
# epoch 82, train loss 0.4348, test loss 0.3416, time 0.1 sec
# epoch 83, train loss 0.4318, test loss 0.3413, time 0.1 sec
# epoch 84, train loss 0.4307, test loss 0.3413, time 0.1 sec
# epoch 85, train loss 0.4323, test loss 0.3411, time 0.1 sec
# epoch 86, train loss 0.4289, test loss 0.3406, time 0.1 sec
# epoch 87, train loss 0.4280, test loss 0.3420, time 0.1 sec
# epoch 88, train loss 0.4271, test loss 0.3447, time 0.1 sec
# epoch 89, train loss 0.4284, test loss 0.3446, time 0.1 sec
# epoch 90, train loss 0.4329, test loss 0.3637, time 0.1 sec
# epoch 91, train loss 0.4350, test loss 0.3402, time 0.1 sec
# epoch 92, train loss 0.4262, test loss 0.3521, time 0.1 sec
# epoch 93, train loss 0.4271, test loss 0.3409, time 0.1 sec
# epoch 94, train loss 0.4269, test loss 0.3393, time 0.1 sec
# epoch 95, train loss 0.4234, test loss 0.3394, time 0.1 sec
# epoch 96, train loss 0.4244, test loss 0.3388, time 0.1 sec
# epoch 97, train loss 0.4260, test loss 0.3385, time 0.1 sec
# epoch 98, train loss 0.4211, test loss 0.3392, time 0.1 sec
# epoch 99, train loss 0.4267, test loss 0.3404, time 0.1 sec
# epoch 100, train loss 0.4236, test loss 0.3386, time 0.1 sec

# %%
# mostra o resultado predito para as 5 primeiras instâncias de teste
y = net(torch.Tensor(test_features[0:5, :]).to(device))
print(y, test_labels[0:5])
# Out:
# tensor([[5.9847],
#         [5.7880],
#         [5.9104],
#         [5.6218],
#         [5.7857]], grad_fn=<AddmmBackward0>) [8. 5. 7. 6. 6.]
